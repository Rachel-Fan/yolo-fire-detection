# %% [markdown]
# # Setup
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/pyproject.toml) and check software and hardware.

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.11  Python-3.10.14 torch-2.1.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MiB)
# Setup complete  (8 CPUs, 11.9 GB RAM, 186.6/237.9 GB disk)

# %% [markdown]
# # 1. Predict
#
# YOLOv8 may be used directly in the Command Line Interface (CLI) with a `yolo` command for a variety of tasks and modes and accepts additional arguments, i.e. `imgsz=640`. See a full list of available `yolo` [arguments](https://docs.ultralytics.com/usage/cfg/) and other details in the [YOLOv8 Predict Docs](https://docs.ultralytics.com/modes/train/).

# %%
# Run inference on an image with YOLOv8n
# !yolo predict model=yolov8n.pt source='C:/Users/Yang_PC/Documents/rfan/Yolo-Fire-dataset/fire/val/images/0.jpg'
# Out:
# ...
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.14 torch-2.1.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 C:\Users\Yang_PC\Documents\rfan\Yolo-Fire-dataset\fire\val\images\0.jpg: 480x640 3 persons, 178.0ms
# Speed: 6.0ms preprocess, 178.0ms inference, 1727.5ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
#   0%|          | 0.00/6.23M [00:00<?, ?B/s]
#   1%|          | 72.0k/6.23M [00:00<00:09, 714kB/s]
#   2%|▏         | 144k/6.23M [00:00<00:11, 551kB/s]
#   3%|▎         | 208k/6.23M [00:00<00:12, 499kB/s]
#   4%|▍         | 264k/6.23M [00:00<00:17, 359kB/s]
#   5%|▌         | 328k/6.23M [00:00<00:14, 419kB/s]
#   6%|▌         | 376k/6.23M [00:00<00:16, 362kB/s]
#   7%|▋         | 440k/6.23M [00:01<00:14, 420kB/s]
#   8%|▊         | 504k/6.23M [00:01<00:13, 433kB/s]
# ...

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="runs/detect/predict/0.jpg" width="600">

# %% [markdown]
# # 2. Val
# Validate a model's accuracy on the [COCO](https://docs.ultralytics.com/datasets/detect/coco/) dataset's `val` or `test` splits. The latest YOLOv8 [models](https://github.com/ultralytics/ultralytics#models) are downloaded automatically the first time they are used. See [YOLOv8 Val Docs](https://docs.ultralytics.com/modes/val/) for more information.

# %%
# Download COCO val
import torch
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017val.zip', 'tmp.zip')  # download (780M - 5000 images)
# !unzip -q tmp.zip -d datasets && rm tmp.zip  # unzip

# %%
# Validate YOLOv8n on COCO8 val
# !yolo val model=yolov8n.pt data=coco8.yaml
# Out:
# Ultralytics YOLOv8.2.3 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# Dataset 'coco8.yaml' images not found ⚠️, missing path '/content/datasets/coco8/images/val'
# ...
# 100% 433k/433k [00:00<00:00, 14.2MB/s]
# Unzipping /content/datasets/coco8.zip to /content/datasets/coco8...: 100% 25/25 [00:00<00:00, 1093.93file/s]
# Dataset download success ✅ (1.3s), saved to /content/datasets
#
# ...
# 100% 755k/755k [00:00<00:00, 17.4MB/s]
# val: Scanning /content/datasets/coco8/labels/val... 4 images, 0 backgrounds, 0 corrupt: 100% 4/4 [00:00<00:00, 157.00it/s]
# val: New cache created: /content/datasets/coco8/labels/val.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:06<00:00,  6.89s/it]
#                    all          4         17      0.621      0.833      0.888       0.63
# ...

# %% [markdown]
# # 3. Train

# %%
# Train YOLOv8n on my own fire dataset for 20 epochs
# !yolo train model=yolov8n.pt data=fire-dataset-path.yaml epochs=20
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.14 torch-2.1.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MiB)
# train: Scanning C:\Users\Yang_PC\Documents\rfan\Yolo-Fire-dataset\fire\train\labels.cache... 3522 images, 5 backgrounds, 3 corrupt: 100%|██████████| 3527/3527 [00:00<?, ?it/s]
# train: Scanning C:\Users\Yang_PC\Documents\rfan\Yolo-Fire-dataset\fire\train\labels.cache... 3522 images, 5 backgrounds, 3 corrupt: 100%|██████████| 3527/3527 [00:00<?, ?it/s]
#
# val: Scanning C:\Users\Yang_PC\Documents\rfan\Yolo-Fire-dataset\fire\val\labels.cache... 150 images, 0 backgrounds, 0 corrupt: 100%|██████████| 150/150 [00:00<?, ?it/s]
# val: Scanning C:\Users\Yang_PC\Documents\rfan\Yolo-Fire-dataset\fire\val\labels.cache... 150 images, 0 backgrounds, 0 corrupt: 100%|██████████| 150/150 [00:00<?, ?it/s]
#
#   0%|          | 0/221 [00:00<?, ?it/s]
#        1/20         2G      2.138      3.458      1.996         69        640:   0%|          | 0/221 [00:05<?, ?it/s]
# ...

# %%
model
# Out:
# {'epoch': -1,
#  'best_fitness': None,
#  'model': DetectionModel(
#    (model): Sequential(
#      (0): Conv(
#        (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#        (act): SiLU(inplace=True)
#      )
#      (1): Conv(
#        (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#        (act): SiLU(inplace=True)
#      )
#      (2): C2f(
#        (cv1): Conv(
#          (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#          (act): SiLU(inplace=True)
#        )
#        (cv2): Conv(
#          (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %% [markdown]
# # 4. Export
#
# Export a YOLOv8 model to any supported format below with the `format` argument, i.e. `format=onnx`. See [YOLOv8 Export Docs](https://docs.ultralytics.com/modes/export/) for more information.
#
# Export to [TensorRT](https://docs.ultralytics.com/integrations/tensorrt/) for up to 5x GPU speedup.

# %%
# !git clone https://github.com/NVIDIA-AI-IOT/torch2trt
# Out:
# fatal: destination path 'torch2trt' already exists and is not an empty directory.

# %%
# %cd torch2trt/
# Out:
# c:\Users\Yang_PC\Documents\Github\yolo-fire-detection\torch2trt

# %%
# !python setup.py install --plugins
# Out:
# running install
# running bdist_egg
# running egg_info
# creating torch2trt.egg-info
# writing torch2trt.egg-info\PKG-INFO
# writing dependency_links to torch2trt.egg-info\dependency_links.txt
# writing top-level names to torch2trt.egg-info\top_level.txt
# writing manifest file 'torch2trt.egg-info\SOURCES.txt'
# reading manifest file 'torch2trt.egg-info\SOURCES.txt'
# adding license file 'LICENSE.md'
# writing manifest file 'torch2trt.egg-info\SOURCES.txt'
# installing library code to build\bdist.win-amd64\egg
# running install_lib
# running build_py
# creating build
# creating build\lib.win-amd64-cpython-310
# creating build\lib.win-amd64-cpython-310\tests
# copying tests\__init__.py -> build\lib.win-amd64-cpython-310\tests
# creating build\lib.win-amd64-cpython-310\torch2trt
# copying torch2trt\dataset.py -> build\lib.win-amd64-cpython-310\torch2trt
# copying torch2trt\dataset_calibrator.py -> build\lib.win-amd64-cpython-310\torch2trt
# ...

# %%
# !yolo export model=last.pt format=tensorrt
# Out:
# WARNING ⚠️ TensorRT requires GPU export, automatically assigning device=0
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.14 torch-2.1.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from 'last.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (6.0 MB)
#
# ONNX: starting export with onnx 1.16.0 opset 17...
# ONNX: export success ✅ 1.1s, saved as 'last.onnx' (11.7 MB)
#
# TensorRT: starting export with TensorRT 8.6.0...
# [05/08/2024-13:32:17] [TRT] [I] [MemUsageChange] Init CUDA: CPU -1, GPU +0, now: CPU 6645, GPU 1332 (MiB)
# [05/08/2024-13:32:26] [TRT] [I] [MemUsageChange] Init builder kernel library: CPU +1441, GPU +262, now: CPU 9061, GPU 1594 (MiB)
# [05/08/2024-13:32:26] [TRT] [I] ----------------------------------------------------------------
# [05/08/2024-13:32:26] [TRT] [I] Input filename:   last.onnx
# ...
